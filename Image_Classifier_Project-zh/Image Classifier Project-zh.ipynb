# %% [markdown]
# # 开发 AI 应用
#
# 未来，AI 算法在日常生活中的应用将越来越广泛。例如，你可能想要在智能手机应用中包含图像分类器。为此，在整个应用架构中，你将使用一个用成百上千个图像训练过的深度学习模型。未来的软件开发很大一部分将是使用这些模型作为应用的常用部分。
#
# 在此项目中，你将训练一个图像分类器来识别不同的花卉品种。可以想象有这么一款手机应用，当你对着花卉拍摄时，它能够告诉你这朵花的名称。在实际操作中，你会训练此分类器，然后导出它以用在你的应用中。我们将使用[此数据集](http://www.robots.ox.ac.uk/~vgg/data/flowers/102/index.html)，其中包含 102 个花卉类别。你可以在下面查看几个示例。
#
# <img src='assets/Flowers.png' width=500px>
#
# 该项目分为多个步骤：
#
# * 加载和预处理图像数据集
# * 用数据集训练图像分类器
# * 使用训练的分类器预测图像内容
#
# 我们将指导你完成每一步，你将用 Python 实现这些步骤。建议在基本完成提示代码的情况下再开启GPU调试。
#
# 完成此项目后，你将拥有一个可以用任何带标签图像的数据集进行训练的应用。你的网络将学习花卉，并成为一个命令行应用。但是，你对新技能的应用取决于你的想象力和构建数据集的精力。例如，想象有一款应用能够拍摄汽车，告诉你汽车的制造商和型号，然后查询关于该汽车的信息。构建你自己的数据集并开发一款新型应用吧。
#
# 首先，导入你所需的软件包。建议在代码开头导入所有软件包。当你创建此 notebook 时，如果发现你需要导入某个软件包，确保在开头导入该软件包。

# %%
# Imports here
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import time
import torch
import json
from torch import nn
from torch import optim
import torch.nn.functional as F
from torch.autograd import Variable
from torchvision import datasets,transforms,models
from collections import OrderedDict
from PIL import Image

# %matplotlib inline
# %config InlineBeckend.figure_format = 'retina'

# %% [markdown]
# ## 加载数据
#
# 在此项目中，你将使用 `torchvision` 加载数据（[文档](http://pytorch.org/docs/master/torchvision/transforms.html#)）。数据应该和此 notebook 一起包含在内，否则你可以[在此处下载数据](https://s3.amazonaws.com/content.udacity-data.com/nd089/flower_data.tar.gz)。数据集分成了三部分：训练集、验证集和测试集。对于训练集，你需要变换数据，例如随机缩放、剪裁和翻转。这样有助于网络泛化，并带来更好的效果。你还需要确保将输入数据的大小调整为 224x224 像素，因为预训练的网络需要这么做。
#
# 验证集和测试集用于衡量模型对尚未见过的数据的预测效果。对此步骤，你不需要进行任何缩放或旋转变换，但是需要将图像剪裁到合适的大小。
#
# 对于所有三个数据集，你都需要将均值和标准差标准化到网络期望的结果。均值为 `[0.485, 0.456, 0.406]`，标准差为 `[0.229, 0.224, 0.225]`。这样使得每个颜色通道的值位于 -1 到 1 之间，而不是 0 到 1 之间。

# %%
train_dir = '/data/flowers/train'
valid_dir = '/data/flowers/valid'
test_dir = '/data/flowers/test'

# %% [markdown]
# 提示：
# - train数据集的transforms需要进行裁剪，均值和标准化，并且要对图像进行随机缩放、剪裁和翻转等等，有助于网络泛化，test和valid数据集的transforms只需要裁剪到合适的大小并进行均值和标准化。综上所述，valid数据集和test数据集使用同一个transform即可
# - 注意需要先resize图片，再crop，否则对于较大图片可能crop不到花朵部分
# - datasets设置时注意参数的变化（目录的不同）
# - loader设置时，train的loader的参数注意设置：shuffle = True，来增加训练图像时的随机性。

# %%
# TODO: 定义transforms
train_transforms = transforms.Compose([transforms.Resize(256),
                                       transforms.CenterCrop(224),
                                       transforms.RandomRotation(30),
                                       transforms.RandomHorizontalFlip(),
                                       transforms.ToTensor(),
                                       transforms.Normalize(mean=[0.485,0.456,0.406],std=[0.229,0.224,0.225])
                                      ])
test_transforms = transforms.Compose([transforms.Resize(256),
                                      transforms.CenterCrop(224),
                                      transforms.ToTensor(),
                                      transforms.Normalize(mean=[0.485,0.456,0.406],std=[0.229,0.224,0.225])
                                     ])
# TODO: 使用dir路径定义datasets，注意配置相对应的transforms
train_datasets = datasets.ImageFolder(train_dir,transform=train_transforms)
valid_datasets = datasets.ImageFolder(valid_dir,transform=test_transforms)
test_datasets = datasets.ImageFolder(test_dir,transform=test_transforms)
# TODO: 使用datasets定义dataloaders
train_loader = torch.utils.data.DataLoader(train_datasets,batch_size=64,shuffle=True)
valid_loader = torch.utils.data.DataLoader(valid_datasets,batch_size=32,shuffle=True)
test_loader = torch.utils.data.DataLoader(test_datasets,batch_size=32,shuffle=True)

# %% [markdown]
# ### 标签映射
#
# 你还需要加载从类别标签到类别名称的映射。你可以在文件 `cat_to_name.json` 中找到此映射。它是一个 JSON 对象，可以使用 [`json` 模块](https://docs.python.org/2/library/json.html)读取它。这样可以获得一个从整数编码的类别到实际花卉名称的映射字典。

# %%
with open('cat_to_name.json', 'r') as f:
    cat_to_name = json.load(f)

# %% [markdown]
# # 构建和训练分类器
#
# 数据准备好后，就开始构建和训练分类器了。和往常一样，你应该使用 `torchvision.models` 中的某个预训练模型获取图像特征。使用这些特征构建和训练新的前馈分类器。
#
# 这部分将由你来完成。如果你想与他人讨论这部分，欢迎与你的同学讨论！你还可以在论坛上提问或在工作时间内咨询我们的课程经理和助教导师。
#
# 请参阅[审阅标准](https://review.udacity.com/#!/rubrics/1663/view)，了解如何成功地完成此部分。你需要执行以下操作：
#
# * 加载[预训练的网络](https://pytorch.org/docs/stable/torchvision/models.html)
# * 使用 ReLU 激活函数和丢弃定义新的未训练前馈网络作为分类器
# * 使用反向传播训练分类器层，并使用预训练的网络获取特征
# * 跟踪验证集的损失和准确率，以确定最佳超参数
#
# 按照提示逐步完成项目，检查确保每部分都达到预期效果，然后再完成下个部分。你可能会发现，当你实现每部分时，可能需要回去修改之前的代码，这很正常！
#
# 训练时，确保仅更新前馈网络的权重。如果一切构建正确的话，验证准确率应该能够超过 70%。确保尝试不同的超参数（学习速率、分类器中的单元、周期等），寻找最佳模型。保存这些超参数并用作项目下个部分的默认值。
#
# 下面让我们开始吧！

# %% [markdown]
# 提示1：
# - 挑选一个模型，加载预训练模型（既然是*预*训练的模型，那么注意参数pretrained应为True）

# %%
# TODO
model = models.vgg16(pretrained=True)

# %% [markdown]
# 提示2：
# - [冻结模型梯度权重](https://pytorch.org/docs/stable/notes/autograd.html?highlight=param%20requires_grad)，设置每一层的param.requires_grad标志

# %%
# TODO
for param in model.parameters():
    param.requires_grad = False

# %% [markdown]
# 提示3：
# - 增加全连接层，dropout层，以及Relu激活函数
# - 修改classifier层的主要目的是为了适应我们的分类要求，即最终的输出层要输出102种花卉分类（即要有一层全连接层输出为102，**不要**在输出层后加dropout）
# - 全连接层后使用[LogSoftmax](https://pytorch.org/docs/stable/nn.html?highlight=nllloss#torch.nn.LogSoftmax)或者[softmax](https://pytorch.org/docs/stable/nn.html?highlight=nllloss#torch.nn.softmax)，来得出每种花的概率

# %%
classifier = nn.Sequential(OrderedDict([
                          ('fc1',nn.Linear(25088,512)),
                          ('relu',nn.ReLU(inplace=True)),
                          ('dropout',nn.Dropout(0.5)),
                          ('fc2',nn.Linear(512,102)),
                          ('output',nn.LogSoftmax(dim=1))
                          ]))

model.classifier = classifier
# 将模型转入gpu
model.cuda()
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (fc1): Linear(in_features=25088, out_features=512, bias=True)
#     (relu): ReLU(inplace)
#     (dropout): Dropout(p=0.5)
#     (fc2): Linear(in_features=512, out_features=102, bias=True)
#     (output): LogSoftmax()
#   )
# )

# %% [markdown]
# 提示4：
# - 设置[损失函数](https://pytorch.org/docs/stable/nn.html?highlight=nllloss#torch.nn.NLLLoss)
# - 设置[优化器](https://pytorch.org/docs/stable/optim.html)

# %%
# TODO
criterion = nn.NLLLoss()
optimizer = optim.Adam(model.classifier.parameters(),lr=0.001)

# %% [markdown]
# 提示5：
# - 分别写成两个函数用于训练模型和测试模型(课程中写到了一个代码中)，便于调试代码，以及增加程序的可读性
# - 因为模型已经转入gpu，这里注意需要将数据也转入gpu
# - 注意输出训练测试过程，把控模型是否欠拟合或者过拟合
# - 模型训练时要model.train()，模型测试时要model.eval()，让模型进入训练或者测试的模式中

# %%
# TODO: 训练网络，需要有loss和accuracy打印输出
def train(model, loader):
    print_every = 20
    steps = 0
    running_loss = 0
    correct = 0
    total = 0
    model.train()
    for ii,(inputs,labels) in enumerate(loader):
        steps += 1
        inputs,labels = inputs.to('cuda'),labels.to('cuda')
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs,labels)
        loss.backward()
        optimizer.step()
        total += labels.size(0)
        running_loss += loss.item()
        _,predicted = torch.max(outputs.data,1)
        correct += (predicted == labels).sum().item()
        print("correct",correct,"running_loss",running_loss,"total",total)
        if steps % print_every == 0:
            model.eval()
            print("Steps:{}..".format(steps),
                  "Training Loss:{:.4f}..".format(running_loss/print_every),
                  "Training accuracy: {:.4f}" .format(correct /total)) 
            running_loss = 0
            correct = 0
            total = 0
            model.train()

# %%
# TODO:测试网络，使用验证集或者测试集，训练模型时使用验证集，测试模型最终结果使用测试集
# 需要有loss和accuracy打印输出
def test(model, loader):
    total = 0
    correct = 0
    running_loss = 0
    model.eval()
    with torch.no_grad():
        for inputs,labels in loader:
            inputs,labels = inputs.to('cuda'),labels.to('cuda')
            outputs = model(inputs)
            loss = criterion(outputs,labels)
            running_loss += loss.item()
            _,predicted = torch.max(outputs.data,1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
            print('this is testing','running_loss',running_loss,'total',total,'correct',correct)

            print("Testing Loss:{:.4f}..".format(loss.item()),
                  "Testing accuracy: {:.4f}" .format(correct /total))

# %%
epoch = 4   #TODO 修改epoch次数
for _ in range(1, epoch):
    train(model, train_loader)
    test(model, valid_loader)
# Out:
# correct 0 running_loss 4.678300380706787 total 64
# correct 5 running_loss 9.662016868591309 total 128
# correct 8 running_loss 15.13839054107666 total 192
# correct 17 running_loss 20.311692237854004 total 256
# correct 23 running_loss 25.110865592956543 total 320
# correct 27 running_loss 30.08740472793579 total 384
# correct 36 running_loss 34.655582904815674 total 448
# correct 51 running_loss 38.442901611328125 total 512
# correct 56 running_loss 42.69844913482666 total 576
# correct 69 running_loss 46.71282386779785 total 640
# correct 77 running_loss 50.976404666900635 total 704
# correct 89 running_loss 54.79425549507141 total 768
# correct 97 running_loss 58.8844997882843 total 832
# correct 111 running_loss 62.65247583389282 total 896
# correct 126 running_loss 66.0481264591217 total 960
# correct 143 running_loss 69.58628106117249 total 1024
# correct 158 running_loss 73.34535884857178 total 1088
# correct 172 running_loss 76.90043687820435 total 1152
# correct 185 running_loss 80.48688006401062 total 1216
# correct 202 running_loss 83.87011432647705 total 1280
# Steps:20.. Training Loss:4.1935.. Training accuracy: 0.1578
# correct 11 running_loss 3.75842022895813 total 64
# correct 22 running_loss 7.392385482788086 total 128
# correct 38 running_loss 10.868405103683472 total 192
# correct 55 running_loss 13.944928169250488 total 256
# correct 71 running_loss 17.158650159835815 total 320
# correct 86 running_loss 20.524702787399292 total 384
# correct 103 running_loss 23.426682949066162 total 448
# correct 128 running_loss 26.386056900024414 total 512
# correct 333 running_loss 18.35027587413788 total 640
# correct 367 running_loss 20.56602966785431 total 704
# correct 404 running_loss 22.33771014213562 total 768
# correct 442 running_loss 24.010048508644104 total 832
# correct 476 running_loss 25.724616169929504 total 896
# correct 514 running_loss 27.472238063812256 total 960
# correct 555 running_loss 28.959763526916504 total 1024
# correct 585 running_loss 30.89686107635498 total 1088
# correct 619 running_loss 32.76553571224213 total 1152
# correct 655 running_loss 34.6678923368454 total 1216
# correct 695 running_loss 36.21920824050903 total 1280
# Steps:100.. Training Loss:1.8110.. Training accuracy: 0.5430
# correct 29 running_loss 2.110102653503418 total 64
# correct 63 running_loss 3.857565402984619 total 128
# correct 75 running_loss 5.715942859649658 total 152
# this is testing running_loss 0.7823814153671265 total 32 correct 26
# Testing Loss:0.7824.. Testing accuracy: 0.8125
# this is testing running_loss 2.1378852128982544 total 64 correct 46
# Testing Loss:1.3555.. Testing accuracy: 0.7188
# this is testing running_loss 2.9460666179656982 total 96 correct 70
# Testing Loss:0.8082.. Testing accuracy: 0.7292
# this is testing running_loss 3.8824084401130676 total 128 correct 92
# Testing Loss:0.9363.. Testing accuracy: 0.7188
# this is testing running_loss 4.513446688652039 total 160 correct 119
# Testing Loss:0.6310.. Testing accuracy: 0.7438
# this is testing running_loss 5.428916394710541 total 192 correct 144
# Testing Loss:0.9155.. Testing accuracy: 0.7500
# this is testing running_loss 7.23600834608078 total 224 correct 168
# Testing Loss:1.8071.. Testing accuracy: 0.7500
# this is testing running_loss 8.110351979732513 total 256 correct 192
# Testing Loss:0.8743.. Testing accuracy: 0.7500
# this is testing running_loss 9.80522745847702 total 288 correct 211
# Testing Loss:1.6949.. Testing accuracy: 0.7326
# this is testing running_loss 10.791032791137695 total 320 correct 234
# Testing Loss:0.9858.. Testing accuracy: 0.7312
# this is testing running_loss 12.388308882713318 total 352 correct 253
# Testing Loss:1.5973.. Testing accuracy: 0.7188
# this is testing running_loss 13.78841233253479 total 384 correct 276
# Testing Loss:1.4001.. Testing accuracy: 0.7188
# this is testing running_loss 14.848384022712708 total 416 correct 301
# Testing Loss:1.0600.. Testing accuracy: 0.7236
# this is testing running_loss 15.975231170654297 total 448 correct 323
# Testing Loss:1.1268.. Testing accuracy: 0.7210
# this is testing running_loss 17.224145650863647 total 480 correct 345
# Testing Loss:1.2489.. Testing accuracy: 0.7188
# this is testing running_loss 18.423757910728455 total 512 correct 365
# Testing Loss:1.1996.. Testing accuracy: 0.7129
# this is testing running_loss 19.277310252189636 total 544 correct 390
# Testing Loss:0.8536.. Testing accuracy: 0.7169
# this is testing running_loss 20.420008540153503 total 576 correct 411
# Testing Loss:1.1427.. Testing accuracy: 0.7135
# this is testing running_loss 21.449166297912598 total 608 correct 437
# Testing Loss:1.0292.. Testing accuracy: 0.7188
# this is testing running_loss 22.41382908821106 total 640 correct 459
# Testing Loss:0.9647.. Testing accuracy: 0.7172
# this is testing running_loss 23.405604243278503 total 672 correct 482
# Testing Loss:0.9918.. Testing accuracy: 0.7173
# this is testing running_loss 24.12710964679718 total 704 correct 507
# correct 543 running_loss 16.96417462825775 total 832
# correct 585 running_loss 18.252696752548218 total 896
# correct 628 running_loss 19.469853281974792 total 960
# correct 671 running_loss 21.00874948501587 total 1024
# correct 720 running_loss 22.14831805229187 total 1088
# correct 759 running_loss 23.40275764465332 total 1152
# correct 802 running_loss 24.632309675216675 total 1216
# correct 843 running_loss 25.975021481513977 total 1280
# Steps:60.. Training Loss:1.2988.. Training accuracy: 0.6586
# correct 45 running_loss 1.0874394178390503 total 64
# correct 90 running_loss 2.109928250312805 total 128
# correct 135 running_loss 3.286868095397949 total 192
# correct 178 running_loss 4.714096903800964 total 256
# correct 221 running_loss 5.873159766197205 total 320
# correct 260 running_loss 7.336729526519775 total 384
# correct 303 running_loss 8.377059817314148 total 448
# correct 342 running_loss 9.597949743270874 total 512
# correct 391 running_loss 10.595121383666992 total 576
# correct 432 running_loss 11.973143696784973 total 640
# correct 471 running_loss 13.560802698135376 total 704
# correct 514 running_loss 14.591484189033508 total 768
# correct 558 running_loss 15.787306427955627 total 832
# correct 603 running_loss 17.052757382392883 total 896
# correct 645 running_loss 18.260339736938477 total 960
# correct 680 running_loss 19.923839926719666 total 1024
# correct 720 running_loss 21.411537051200867 total 1088
# correct 759 running_loss 22.91488230228424 total 1152
# correct 801 running_loss 24.063417553901672 total 1216
# correct 841 running_loss 25.502017736434937 total 1280
# Steps:80.. Training Loss:1.2751.. Training accuracy: 0.6570
# correct 40 running_loss 1.2459355592727661 total 64
# correct 84 running_loss 2.313823699951172 total 128
# correct 128 running_loss 3.5339953899383545 total 192
# correct 169 running_loss 4.822386622428894 total 256
# correct 205 running_loss 6.447015047073364 total 320
# correct 247 running_loss 7.7020875215530396 total 384
# correct 289 running_loss 8.953554391860962 total 448
# correct 330 running_loss 10.15278673171997 total 512
# correct 376 running_loss 11.198261618614197 total 576
# correct 411 running_loss 12.762957692146301 total 640
# correct 455 running_loss 14.105220794677734 total 704
# correct 498 running_loss 15.591688752174377 total 768
# correct 546 running_loss 16.398097038269043 total 832
# correct 592 running_loss 17.549434900283813 total 896
# correct 633 running_loss 18.75677239894867 total 960
# correct 671 running_loss 20.21872389316559 total 1024
# correct 714 running_loss 21.208721935749054 total 1088
# correct 761 running_loss 22.339061677455902 total 1152
# correct 809 running_loss 23.202470064163208 total 1216
# correct 856 running_loss 24.295713186264038 total 1280
# Steps:100.. Training Loss:1.2148.. Training accuracy: 0.6687
# correct 40 running_loss 1.2797560691833496 total 64
# correct 82 running_loss 2.616629719734192 total 128
# correct 102 running_loss 3.498764932155609 total 152
# this is testing running_loss 1.1938669681549072 total 32 correct 25
# Testing Loss:1.1939.. Testing accuracy: 0.7812
# this is testing running_loss 1.7348101735115051 total 64 correct 53
# Testing Loss:0.5409.. Testing accuracy: 0.8281
# this is testing running_loss 2.689716398715973 total 96 correct 77
# Testing Loss:0.9549.. Testing accuracy: 0.8021
# this is testing running_loss 3.304618239402771 total 128 correct 105
# Testing Loss:0.6149.. Testing accuracy: 0.8203
# this is testing running_loss 4.330231666564941 total 160 correct 126
# Testing Loss:1.0256.. Testing accuracy: 0.7875
# this is testing running_loss 4.70853328704834 total 192 correct 157
# Testing Loss:0.3783.. Testing accuracy: 0.8177
# this is testing running_loss 5.852891206741333 total 224 correct 178
# Testing Loss:1.1444.. Testing accuracy: 0.7946
# this is testing running_loss 6.549784064292908 total 256 correct 202
# Testing Loss:0.6969.. Testing accuracy: 0.7891
# this is testing running_loss 7.094334006309509 total 288 correct 227
# Testing Loss:0.5445.. Testing accuracy: 0.7882
# this is testing running_loss 7.94089013338089 total 320 correct 251
# Testing Loss:0.8466.. Testing accuracy: 0.7844
# this is testing running_loss 8.746326446533203 total 352 correct 277
# Testing Loss:0.8054.. Testing accuracy: 0.7869
# this is testing running_loss 9.677279233932495 total 384 correct 302
# Testing Loss:0.9310.. Testing accuracy: 0.7865
# this is testing running_loss 10.251676440238953 total 416 correct 329
# Testing Loss:0.5744.. Testing accuracy: 0.7909
# this is testing running_loss 11.453239440917969 total 448 correct 350
# Testing Loss:1.2016.. Testing accuracy: 0.7812
# this is testing running_loss 11.7847281396389 total 480 correct 378
# Testing Loss:0.3315.. Testing accuracy: 0.7875
# this is testing running_loss 12.535978466272354 total 512 correct 405
# Testing Loss:0.7513.. Testing accuracy: 0.7910
# this is testing running_loss 13.153160005807877 total 544 correct 434
# Testing Loss:0.6172.. Testing accuracy: 0.7978
# this is testing running_loss 14.328999429941177 total 576 correct 457
# Testing Loss:1.1758.. Testing accuracy: 0.7934
# this is testing running_loss 14.86391469836235 total 608 correct 483
# Testing Loss:0.5349.. Testing accuracy: 0.7944
# this is testing running_loss 15.370522171258926 total 640 correct 510
# Testing Loss:0.5066.. Testing accuracy: 0.7969
# this is testing running_loss 16.843918710947037 total 672 correct 537
# Testing Loss:1.4734.. Testing accuracy: 0.7991
# this is testing running_loss 17.72040554881096 total 704 correct 561
# Testing Loss:0.8765.. Testing accuracy: 0.7969
# this is testing running_loss 18.08702141046524 total 736 correct 592
# Testing Loss:0.3666.. Testing accuracy: 0.8043
# this is testing running_loss 18.678666710853577 total 768 correct 622
# Testing Loss:0.5916.. Testing accuracy: 0.8099
# this is testing running_loss 19.037345707416534 total 800 correct 652
# Testing Loss:0.3587.. Testing accuracy: 0.8150
# this is testing running_loss 19.726959109306335 total 818 correct 667
# Testing Loss:0.6896.. Testing accuracy: 0.8154
# correct 47 running_loss 0.8401382565498352 total 64
# correct 95 running_loss 1.9470929503440857 total 128
# correct 143 running_loss 2.974394381046295 total 192
# correct 187 running_loss 4.138578951358795 total 256
# correct 230 running_loss 5.385370910167694 total 320
# correct 278 running_loss 6.272700905799866 total 384
# correct 330 running_loss 7.03520655632019 total 448
# correct 372 running_loss 8.022904753684998 total 512
# correct 413 running_loss 9.38335108757019 total 576
# correct 458 running_loss 10.496057152748108 total 640
# correct 508 running_loss 11.359641671180725 total 704
# correct 555 running_loss 12.407016396522522 total 768
# correct 603 running_loss 13.233726143836975 total 832
# correct 653 running_loss 14.227565824985504 total 896
# correct 777 running_loss 16.679278075695038 total 1088
# correct 823 running_loss 17.847873628139496 total 1152
# correct 872 running_loss 18.748190343379974 total 1216
# correct 917 running_loss 19.60535627603531 total 1280
# Steps:80.. Training Loss:0.9803.. Training accuracy: 0.7164
# correct 47 running_loss 0.9609290957450867 total 64
# correct 99 running_loss 1.8044868111610413 total 128
# correct 149 running_loss 2.5012391209602356 total 192
# correct 195 running_loss 3.311511754989624 total 256
# correct 237 running_loss 4.520318865776062 total 320
# correct 280 running_loss 5.755368709564209 total 384
# correct 324 running_loss 6.7360106110572815 total 448
# correct 370 running_loss 7.998369634151459 total 512
# correct 418 running_loss 8.865180611610413 total 576
# correct 462 running_loss 9.798325419425964 total 640
# correct 513 running_loss 10.5168616771698 total 704
# correct 558 running_loss 11.574465870857239 total 768
# correct 604 running_loss 12.529111504554749 total 832
# correct 646 running_loss 13.56363046169281 total 896
# correct 690 running_loss 14.592676639556885 total 960
# correct 742 running_loss 15.339535593986511 total 1024
# correct 791 running_loss 16.280847191810608 total 1088
# correct 834 running_loss 17.47987723350525 total 1152
# correct 880 running_loss 18.495052576065063 total 1216
# correct 928 running_loss 19.406553149223328 total 1280
# Steps:100.. Training Loss:0.9703.. Training accuracy: 0.7250
# correct 41 running_loss 1.2618403434753418 total 64
# correct 86 running_loss 2.383438467979431 total 128
# correct 103 running_loss 3.483262062072754 total 152
# this is testing running_loss 0.42749565839767456 total 32 correct 29
# Testing Loss:0.4275.. Testing accuracy: 0.9062
# this is testing running_loss 1.3161541819572449 total 64 correct 54
# Testing Loss:0.8887.. Testing accuracy: 0.8438
# this is testing running_loss 2.1082170009613037 total 96 correct 79
# Testing Loss:0.7921.. Testing accuracy: 0.8229
# this is testing running_loss 2.646253287792206 total 128 correct 107
# Testing Loss:0.5380.. Testing accuracy: 0.8359
# this is testing running_loss 3.2599201798439026 total 160 correct 134
# Testing Loss:0.6137.. Testing accuracy: 0.8375
# this is testing running_loss 3.8616814613342285 total 192 correct 160
# Testing Loss:0.6018.. Testing accuracy: 0.8333
# this is testing running_loss 4.595887184143066 total 224 correct 185
# Testing Loss:0.7342.. Testing accuracy: 0.8259
# this is testing running_loss 5.527050137519836 total 256 correct 208
# Testing Loss:0.9312.. Testing accuracy: 0.8125
# this is testing running_loss 5.804430365562439 total 288 correct 239
# Testing Loss:0.2774.. Testing accuracy: 0.8299
# this is testing running_loss 6.245549529790878 total 320 correct 267
# Testing Loss:0.4411.. Testing accuracy: 0.8344
# this is testing running_loss 6.520572364330292 total 352 correct 296
# Testing Loss:0.2750.. Testing accuracy: 0.8409
# this is testing running_loss 6.8114228546619415 total 384 correct 324
# Testing Loss:0.2909.. Testing accuracy: 0.8438
# this is testing running_loss 8.469771891832352 total 416 correct 353
# Testing Loss:1.6583.. Testing accuracy: 0.8486
# this is testing running_loss 8.817657500505447 total 448 correct 381
# Testing Loss:0.3479.. Testing accuracy: 0.8504
# this is testing running_loss 9.503868013620377 total 480 correct 407
# Testing Loss:0.6862.. Testing accuracy: 0.8479
# this is testing running_loss 9.777725487947464 total 512 correct 437
# Testing Loss:0.2739.. Testing accuracy: 0.8535
# this is testing running_loss 10.331574648618698 total 544 correct 464
# Testing Loss:0.5538.. Testing accuracy: 0.8529
# this is testing running_loss 11.078460425138474 total 576 correct 490
# Testing Loss:0.7469.. Testing accuracy: 0.8507
# this is testing running_loss 11.619810551404953 total 608 correct 516
# Testing Loss:0.5414.. Testing accuracy: 0.8487
# this is testing running_loss 12.1927829682827 total 640 correct 543
# Testing Loss:0.5730.. Testing accuracy: 0.8484
# this is testing running_loss 12.664970070123672 total 672 correct 571
# Testing Loss:0.4722.. Testing accuracy: 0.8497
# this is testing running_loss 13.3105848133564 total 704 correct 598
# Testing Loss:0.6456.. Testing accuracy: 0.8494
# this is testing running_loss 13.61890795826912 total 736 correct 628
# Testing Loss:0.3083.. Testing accuracy: 0.8533
# this is testing running_loss 14.166210502386093 total 768 correct 657
# Testing Loss:0.5473.. Testing accuracy: 0.8555
# this is testing running_loss 15.058995217084885 total 800 correct 683
# Testing Loss:0.8928.. Testing accuracy: 0.8538
# this is testing running_loss 15.398325651884079 total 818 correct 699
# Testing Loss:0.3393.. Testing accuracy: 0.8545

# %% [markdown]
# ## 测试网络
#
# 建议使用网络在训练或验证过程中从未见过的测试数据测试训练的网络。这样，可以很好地判断模型预测全新图像的效果。用网络预测测试图像，并测量准确率，就像验证过程一样。如果模型训练良好的话，你应该能够达到大约 70% 的准确率。

# %%
# TODO: 在测试集上进行测试，需要输出结果
test(model, test_loader)
# Out:
# this is testing running_loss 0.6546366214752197 total 32 correct 25
# Testing Loss:0.6546.. Testing accuracy: 0.7812
# this is testing running_loss 1.1017916798591614 total 64 correct 53
# Testing Loss:0.4472.. Testing accuracy: 0.8281
# this is testing running_loss 1.8514253497123718 total 96 correct 80
# Testing Loss:0.7496.. Testing accuracy: 0.8333
# this is testing running_loss 2.5083486437797546 total 128 correct 108
# Testing Loss:0.6569.. Testing accuracy: 0.8438
# this is testing running_loss 3.01610004901886 total 160 correct 133
# Testing Loss:0.5078.. Testing accuracy: 0.8313
# this is testing running_loss 3.653795599937439 total 192 correct 160
# Testing Loss:0.6377.. Testing accuracy: 0.8333
# this is testing running_loss 4.2900519371032715 total 224 correct 188
# Testing Loss:0.6363.. Testing accuracy: 0.8393
# this is testing running_loss 5.075019299983978 total 256 correct 212
# Testing Loss:0.7850.. Testing accuracy: 0.8281
# this is testing running_loss 5.941669523715973 total 288 correct 234
# Testing Loss:0.8667.. Testing accuracy: 0.8125
# this is testing running_loss 7.215319931507111 total 320 correct 257
# Testing Loss:1.2737.. Testing accuracy: 0.8031
# this is testing running_loss 7.612606227397919 total 352 correct 284
# Testing Loss:0.3973.. Testing accuracy: 0.8068
# this is testing running_loss 8.582771897315979 total 384 correct 309
# Testing Loss:0.9702.. Testing accuracy: 0.8047
# this is testing running_loss 9.219284892082214 total 416 correct 338
# Testing Loss:0.6365.. Testing accuracy: 0.8125
# this is testing running_loss 9.911150932312012 total 448 correct 363
# Testing Loss:0.6919.. Testing accuracy: 0.8103
# this is testing running_loss 10.739091992378235 total 480 correct 388
# Testing Loss:0.8279.. Testing accuracy: 0.8083
# this is testing running_loss 11.53688532114029 total 512 correct 413
# Testing Loss:0.7978.. Testing accuracy: 0.8066
# this is testing running_loss 12.192299127578735 total 544 correct 438
# Testing Loss:0.6554.. Testing accuracy: 0.8051
# this is testing running_loss 12.764575839042664 total 576 correct 465
# Testing Loss:0.5723.. Testing accuracy: 0.8073
# this is testing running_loss 13.213390320539474 total 608 correct 493
# Testing Loss:0.4488.. Testing accuracy: 0.8109
# this is testing running_loss 13.938969403505325 total 640 correct 519
# Testing Loss:0.7256.. Testing accuracy: 0.8109
# this is testing running_loss 14.7830670773983 total 672 correct 546
# Testing Loss:0.8441.. Testing accuracy: 0.8125
# this is testing running_loss 15.302126437425613 total 704 correct 575
# Testing Loss:0.5191.. Testing accuracy: 0.8168
# this is testing running_loss 16.01774337887764 total 736 correct 599
# Testing Loss:0.7156.. Testing accuracy: 0.8139
# this is testing running_loss 16.812595397233963 total 768 correct 624
# Testing Loss:0.7949.. Testing accuracy: 0.8125
# this is testing running_loss 17.088504880666733 total 800 correct 654
# Testing Loss:0.2759.. Testing accuracy: 0.8175
# this is testing running_loss 17.59528276324272 total 819 correct 669
# Testing Loss:0.5068.. Testing accuracy: 0.8168

# %% [markdown]
# ## 保存检查点
#
# 训练好网络后，[保存模型](https://pytorch.org/docs/stable/torch.html?highlight=torch%20save#torch.save)，以便稍后加载它并进行预测。你可能还需要保存其他内容，例如从类别到索引的映射，索引是从某个图像数据集中获取的：`image_datasets['train'].class_to_idx`。你可以将其作为属性附加到模型上，这样稍后推理会更轻松。

# %% [markdown]
# 提示：
# - 创建checkpoint字典，字典中最少需要包含模型model相关和题目中要求的image_datasets['train'].class_to_idx
# - 使用torch.save保存checkpoint字典

# %%
# TODO: Save the checkpoint 
checkpoint = {'features': model.features,
             'classifier':model.classifier,
             'state_dict':model.state_dict(),
             'class_to_idx':train_datasets.class_to_idx}
torch.save(checkpoint,'checkpoint.pth')

# %% [markdown]
# ## 加载检查点
#
# 此刻，建议写一个可以加载检查点并重新构建模型的函数。这样的话，你可以回到此项目并继续完善它，而不用重新训练网络。

# %% [markdown]
# 提示：
# - 加载”保存检查点“所保存的文件，用于恢复模型
# - 注意torch的save会原模原样保存你需要保存的数据，因为你保存的是字典，从文件加载出来的就是一个字典类型的数据，按照字典方式操作即可。比如
# ```
# #保存：
# dict1 = {"A" : 1, "B": 2}
# torch.save(dict1, filepath)
# #加载：
# checkpoint = torch.load(filepath)
# A = checkpoint["A"]
# B = checkpoint["B"]
# ```
# - image_datasets['train'].class_to_idx，这个是指花朵本身对应的文件夹名称（数字）到模型预测出来的名称（数字）的一个对应关系，是一个字典形式，为了后面方便查询（通过预测出来的名称来得到真正的花朵所在文件夹的名称），这里需要将class_to_idx这个字典键key和值value颠倒过来
# - 题目要求是函数，所以函数最终需要返回可以用于预测的模型以及颠倒后的class_to_idx

# %%
# TODO: Write a function that loads a checkpoint and rebuilds the model
def load_checkpoint(filepath):
    checkpoint = torch.load('checkpoint.pth')
    model = models.vgg16(pretrained=True)
    model.classifier = checkpoint['classifier']
    model.load_state_dict(checkpoint['state_dict'])
    class_to_idx = checkpoint['class_to_idx']
    class_to_idx = dict(zip(class_to_idx.values(),class_to_idx.keys()))
    model.class_to_idx = class_to_idx
    return model,class_to_idx

# %%
model, class_to_idx = load_checkpoint('checkpoint.pth')

# %%
model.cuda()
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (fc1): Linear(in_features=25088, out_features=512, bias=True)
#     (relu): ReLU(inplace)
#     (dropout): Dropout(p=0.5)
#     (fc2): Linear(in_features=512, out_features=102, bias=True)
#     (output): LogSoftmax()
#   )
# )

# %% [markdown]
# # 类别推理

# %% [markdown]
# 首先，你需要处理输入图像，使其可以用于你的网络。
#
# ## 图像处理
#
# 你需要使用 `PIL` 加载图像（[文档](https://pillow.readthedocs.io/en/latest/reference/Image.html)）。建议写一个函数来处理图像，使图像可以作为模型的输入。该函数应该按照训练的相同方式处理图像。
#
# 首先，调整图像大小，使最小的边为 256 像素，并保持宽高比。为此，可以使用 [`thumbnail`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) 或 [`resize`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) 方法。然后，你需要从图像的中心裁剪出 224x224 的部分。
#
# 图像的颜色通道通常编码为整数 0-255，但是该模型要求值为浮点数 0-1。你需要变换值。使用 Numpy 数组最简单，你可以从 PIL 图像中获取，例如 `np_image = np.array(pil_image)`。
#
# 和之前一样，网络要求图像按照特定的方式标准化。均值应标准化为 `[0.485, 0.456, 0.406]`，标准差应标准化为 `[0.229, 0.224, 0.225]`。你需要用每个颜色通道减去均值，然后除以标准差。
#
# 最后，PyTorch 要求颜色通道为第一个维度，但是在 PIL 图像和 Numpy 数组中是第三个维度。你可以使用 [`ndarray.transpose`](https://docs.scipy.org/doc/numpy-1.13.0/reference/generated/numpy.ndarray.transpose.html)对维度重新排序。颜色通道必须是第一个维度，并保持另外两个维度的顺序。

# %% [markdown]
# 提示：
# - 按照上述要求来写即可，特别提示维度排序：np_image.transpose((2, 0, 1))，这个样子是指将第三个维度（颜色）换到了第一个维度上，其他两个维度保持顺序
# - 另外要注意，np和PIL的很多操作都是在返回值中进行修改，而不会对原数据进行修改，务必要进行赋值操作
# - 运行下面的测试，如果出现下面的图，则编写正确：
# <img src='assets/1_flower.png'>

# %%
def process_image(image):
    ''' Scales, crops, and normalizes a PIL image for a PyTorch model,
        returns an Numpy array
    '''
    im = img_resize(image)
    im = clipResizeImg(im)
    np_image = norm_std(im)
    np_image = np_image.transpose((2, 0, 1))
    return np_image
    # TODO: Process a PIL image for use in a PyTorch model
def img_resize(image,ax=None, title=None):
    im = Image.open(image)
    width,height = im.size[0],im.size[1]
    if width > height:
        width = int(width * (256/height))
        height = 256
    else:
        height = int(height * (256/width))
        width = 256
    im = im.resize((width,height),Image.ANTIALIAS)
    return im
def clipResizeImg(image,ax=None, title=None):
    width,height = image.size
    new_width = 224
    new_height = 224
    x = int((width - new_width)/2)
    y = int((height - new_height)/2)
    box = (x,y,x+new_width,y+new_height)
    newIm = image.crop(box)
    return newIm
def norm_std(image):
    im_np = np.array(image)
    im_np = (im_np - np.min(im_np))/(np.max(im_np)-np.min(im_np))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    image = (im_np - mean)/std
    return image

# %% [markdown]
# 要检查你的项目，可以使用以下函数来转换 PyTorch 张量并将其显示在  notebook 中。如果 `process_image` 函数可行，用该函数运行输出应该会返回原始图像（但是剪裁掉的部分除外）。

# %%
def imshow(image, ax=None, title=None):
    """Imshow for Tensor."""
    if ax is None:
        fig, ax = plt.subplots()
    
    # PyTorch tensors assume the color channel is the first dimension
    # but matplotlib assumes is the third dimension
    image = image.transpose((1, 2, 0))
    
    # Undo preprocessing
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    image = std * image + mean
    
    # Image needs to be clipped between 0 and 1 or it looks like noise when displayed
    image = np.clip(image, 0, 1)
    
    ax.imshow(image)
    
    return ax

# %% [markdown]
# 测试一下，跟提示中出现同样的花朵后才可进行下一道题：

# %%
img_tensor = process_image(train_dir+"/1/image_06735.jpg")

# %%
imshow(img_tensor)

# %% [markdown]
# ## 类别预测
#
# 可以获得格式正确的图像后
#
# 现在，使用训练的网络进行推理的函数。即你将向网络中传入一个图像路径，并预测图像中的花卉类别。这里实现了 `predict` 的函数，该函数会接受图像和模型，然后返回概率在前 $K$ 的类别及其概率。
#
# 要获得前 $K$ 个值，在张量中使用 [`x.topk(k)`](http://pytorch.org/docs/master/torch.html#torch.topk)。该函数会返回前 `k` 个概率和对应的类别索引。使用  `class_to_idx`将这些索引转换为实际类别标签，或者从用来加载数据的[ `ImageFolder`](https://pytorch.org/docs/master/torchvision/datasets.html?highlight=imagefolder#torchvision.datasets.ImageFolder)进行转换。

# %%
# 只是示例，不要运行，可以看出predict接收了图像的path以及加载出来的模型，返回了预测的种类索引和各个种类的概率
probs, classes = predict(image_path, model)
print(probs)
print(classes)
> [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
> ['70', '3', '45', '62', '55']
# Out:
#   File "<ipython-input-34-dce83f5b312e>", line 5
#     > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
#     ^
# SyntaxError: invalid syntax

# %%
# 不需要修改，运行即可
def predict(image_path, model, topk=5):
    ''' Predict the class (or classes) of an image using a trained deep learning model.
    '''
    model.eval()
    img_tensor = process_image(image_path)
    img_tensor=torch.from_numpy(img_tensor)
    img_tensor.unsqueeze_(0)
    img_tensor = img_tensor.type(torch.cuda.FloatTensor)
    output = model(Variable(img_tensor.cuda(), volatile=True))
    ps = torch.exp(output)
    probs, index = ps.topk(topk)
    probs = probs.cpu().detach().numpy().tolist()[0]
    index = index.cpu().detach().numpy().tolist()[0]
    index = [class_to_idx[i] for i in index]
    return probs, index

# %% [markdown]
# 尝试调用预测一下，如果你的模型测出来概率最高的那个种类是1，即可进行下一道题的操作，否则你可能需要反复修改之前所有涉及到模型的问题，或者检查下加载检查点中的class_to_idx是否正确颠倒。

# %%
probs, classes = predict(train_dir+"/1/image_06735.jpg", model)
print(probs)
print(classes)
# Out:
# [0.42789357900619507, 0.10996496677398682, 0.102152019739151, 0.07186682522296906, 0.06885276734828949]
# ['1', '86', '51', '55', '82']
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:10: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   # Remove the CWD from sys.path while we load stuff.

# %% [markdown]
# ## 检查运行状况
#
# 你已经可以使用训练的模型做出预测，现在检查模型的性能如何。即使测试准确率很高，始终有必要检查是否存在明显的错误。使用 `matplotlib` 将前 5 个类别的概率以及输入图像绘制为条形图，应该如下所示：
#
# <img src='assets/inference_example.png' width=300px>
#
# 你可以使用 `cat_to_name.json` 文件（应该之前已经在 notebook 中加载该文件）将类别整数编码转换为实际花卉名称。要将 PyTorch 张量显示为图像，请使用定义如下的 `imshow` 函数。

# %% [markdown]
# 提示：
# - cat_to_name.json是文件夹的目录和真实花朵名称的对应关系，通过上一步predict得出的index对应到cat_to_name即可得到名称

# %%
# TODO: Display an image along with the top 5 classes
# 参数分别为测试花朵的路径，花朵种类的文件夹名称，模型，以及topk
def show_result(path, classname, model, topk):
    probs, classes = predict(path, model)
    names = [cat_to_name[str(index)] for index in classes]
    data = pd.Series(data=probs,index=names)
    data.sort_values(ascending = False,inplace=True)
    plt.barh(data.index,data.values,height = 0.5)
    imshow(process_image(path))

    
    print(probs, classes)

# %% [markdown]
# 接下来测试一下，希望你绘制的图中，概率最高的花朵种类名称为trumpet creeper。

# %%
#直接运行
show_result(test_dir+"/101/image_07949.jpg", "101", model, 5)
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:10: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   # Remove the CWD from sys.path while we load stuff.
# [0.25624772906303406, 0.2513735592365265, 0.20237712562084198, 0.12300106883049011, 0.057669498026371] ['101', '26', '96', '51', '97']
